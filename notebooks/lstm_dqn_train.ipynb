# %%
#@title Setup environment

# Get source code from github.  
# Download dataset, which is shared from google drive.  
# Install all dependencies and required packages.

from IPython.display import clear_output

# clone github repo
# !git clone --branch master --single-branch https://github.com/pybnen/conbas.git

# download data
# %cd /content/conbas/conbas/data/
# !./download_data.sh
# %cd /content/conbas

# install required package
# install textworld, follow install instructions https://github.com/microsoft/textworld#installation
# !sudo apt update && sudo apt install build-essential libffi-dev python3-dev curl git
# !pip install textworld

# clear log output and print summary
clear_output(wait=True)
print("[DONE] Clone github repo")
print("[DONE] Download data")
print("[DONE] Install required package")

# %%
#@title Run tensorboard

# %load_ext tensorboard
# %tensorboard --logdir /content/conbas/experiments

# %%
#@title Train model
# !cd /content/conbas/
# !python conbas/agents/lstm_dqn/train.py
